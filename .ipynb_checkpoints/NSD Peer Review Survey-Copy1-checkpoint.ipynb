# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pylab
import scipy as sp
import scipy.stats as sps
import seaborn as sns

from IPython.display import display
from textwrap import wrap

# %%
import plotly.plotly as py

# %% [markdown]
# #### Define graph style

# %%
pylab.rcParams['figure.figsize'] = (8.0, 6.0)

# paramaters for saved figures
pylab.rcParams['savefig.bbox'] = 'tight'
pylab.rcParams['savefig.dpi'] = 300

# set base Seaborn style
sns.set_style("white", 
              {'font.sans-serif': ['Helevetica', 'Liberation Sans', 
                                   'Bitstream Vera Sans', 'sans-serif'],
               'axes.linewidth': 0,
               'xtick.direction': 'in',
               'xtick.major.size': 6.0})


def apply_cdl_style(fig):
    """
    Applies some elemnts of CDL house style.
    fig: matplolib figure object
    """
    
    # kill left axis chartjunk
    fig.set_ylabel('')
    sns.despine(ax=fig, left=True)

    # get rid of Pandas dashed line
    fig.lines[0].set_visible(False) 
    
    #set font sizes
    fig.tick_params(axis='x', width=2, labelsize=12, color='#808080')
    fig.tick_params(axis='y', labelsize=12)
    
    return fig

# %%
def graph_likert(questions, answers, label_width=25, legend_width=10, divergent=False):
    
    collected_counts = pd.DataFrame(index=answers)
    mean = pd.Series(index=questions.columns)

    # set up dict for converstion from likert scale (e.g., 1-5) to 0-100%
    number_of_answers = len(answers) 
    answer_to_value = dict(zip(answers, np.arange(number_of_answers)/float(number_of_answers - 1)*100)) 

    for column in questions.columns:
        collected_counts[column] = questions[column].value_counts().dropna()

        #scale responses to go from 0 to 100
        likert_values = questions[column].dropna().map(answer_to_value)
        mean[column] = likert_values.mean() 
        
    #sort collected_counts by the mean   
    mean.sort()
    collected_counts = collected_counts.T.reindex(index=mean.index)
    collected_counts = collected_counts.div(collected_counts.sum(1).astype(float)/100, axis = 0)
    
    
    collected_counts.index = [ '\n'.join(wrap(i, label_width)) for i in collected_counts.index ]
    collected_counts.columns = [ '\n'.join(wrap(i, legend_width)) for i in collected_counts.columns ]
    
    palette = "RdBu_r" if divergent else "Blues"
    
    # plot percentages of each response
    fig = collected_counts.plot(kind='barh', stacked=True, grid=False, 
                                color=sns.color_palette(palette, len(collected_counts.columns))[::-1],
                                xlim = (0,100), edgecolor='w', linewidth=2) 
    
    # plot mean
    fig.plot(mean, np.arange(len(mean)), marker='o', color='w',axes=fig, 
             markersize=25, markeredgewidth=0, linewidth=0)
    
    
    fig.legend(bbox_to_anchor=(0., -0.02, 1., -0.03), loc='upper left', ncol=number_of_answers, mode="expand",
                    borderaxespad=0., fontsize=12)
    
    apply_cdl_style(fig)
    
    fig.get_figure().set_size_inches(12., 2. * len(collected_counts.index))

    return fig#, collected_counts

# %%
def graph_likert_plotly(questions, answers, label_width=25, legend_width=10, divergent=False):
    
    collected_counts = pd.DataFrame(index=answers)
    mean = pd.Series(index=questions.columns)

    # set up dict for converstion from likert scale (e.g., 1-5) to 0-100%
    number_of_answers = len(answers) 
    answer_to_value = dict(zip(answers, np.arange(number_of_answers)/float(number_of_answers - 1)*100)) 

    for column in questions.columns:
        collected_counts[column] = questions[column].value_counts().dropna()

        #scale responses to go from 0 to 100
        likert_values = questions[column].dropna().map(answer_to_value)
        mean[column] = likert_values.mean() 
        
    #sort collected_counts by the mean   
    mean.sort()
    collected_counts = collected_counts.T.reindex(index=mean.index)
    collected_counts = collected_counts.div(collected_counts.sum(1).astype(float)/100, axis = 0)
    
    
    collected_counts.index = [ '\n'.join(wrap(i, label_width)) for i in collected_counts.index ]
    collected_counts.columns = [ '\n'.join(wrap(i, legend_width)) for i in collected_counts.columns ]
    
    palette = "RdBu_r" if divergent else "Blues"
    
    # plot percentages of each response
    fig = collected_counts.plot(kind='barh', stacked=True, grid=False, 
                                color=sns.color_palette(palette, len(collected_counts.columns))[::-1],
                                xlim = (0,100), edgecolor='w', linewidth=2, legend=False) 
    
    # plot mean
    fig.plot(mean, np.arange(len(mean)), marker='o', color='w',axes=fig, 
             markersize=25, markeredgewidth=0, linewidth=0)
    
    
    #fig.legend(bbox_to_anchor=(0., -0.02, 1., -0.03), loc='upper left', ncol=number_of_answers, mode="expand",
    #                borderaxespad=0., fontsize=12)
    
    apply_cdl_style(fig)
    fig.tick_params(which='both',
                    labelbottom='off',
                    labelleft='off')
    
    fig.get_figure().set_size_inches(12., 2. * len(collected_counts.index))

    return fig#, collected_counts

# %%
responses = pd.read_csv('FINAL_Author_Insights_2014.tsv', 
                        sep=None,
                        engine='python')

# %%
PR_STATEMENTS = ["I am frequently frustrated by the length of time the process of peer review takes",
                 "Traditional peer review processes are effective in ensuring the high quality of published content",
                 "Traditional peer review processes could be made more efficient",
                 "Publishers should experiment with alternative peer review methods",
                 "I think the peer review process should be more transparent"]

PR_VARIATIONS = ["Publish signed reviews",
                 "Crowd sourced peer review",
                 "Post-publication peer review",
                 "Double-blind peer review",
                 "Open peer review"]

# %%
pr_statements = responses.loc[:,'Peer review statements loop_1' : 
                                'Peer review statements loop_5']
pr_statements.columns = PR_STATEMENTS

pr_variations = responses.loc[:,'Variations on traditional peer review loop_1' : 
                                'Variations on traditional peer review loop_5']
pr_variations.columns = PR_VARIATIONS

# %%
AGREEMENT_LEVELS = ["Strongly disagree", 
                    "Disagree",
                    "Neither agree nor disagree",
                    "Agree",
                    "Strongly agree"]
IDEA_LEVELS = ["This is a bad idea",
               "This is not a very good idea",
               "This is quite a good idea",
               "This is a very good idea"]

# %%
graph_likert(pr_statements, AGREEMENT_LEVELS, label_width=30, divergent=True)

# %%
graph_likert_plotly(pr_variations, IDEA_LEVELS, divergent=True)

# %%
fig = plt.gcf()
plot_url = py.iplot_mpl(fig, filename="pr_variations")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-88e4e67e204c> in <module>()
#       1 fig = plt.gcf()
# ----> 2 plot_url = py.iplot_mpl(fig, filename="pr_variations")
#
# /Users/kratzscience/anaconda/lib/python3.4/site-packages/plotly/plotly/plotly.py in iplot_mpl(fig, resize, strip_style, update, **plot_options)
#     220
#     221     """
# --> 222     fig = tools.mpl_to_plotly(fig, resize=resize, strip_style=strip_style)
#     223     if update and isinstance(update, dict):
#     224         try:
#
# /Users/kratzscience/anaconda/lib/python3.4/site-packages/plotly/tools.py in mpl_to_plotly(fig, resize, strip_style, verbose)
#     376     if _matplotlylib_imported:
#     377         renderer = matplotlylib.PlotlyRenderer()
# --> 378         matplotlylib.Exporter(renderer).run(fig)
#     379         if resize:
#     380             renderer.resize()
#
# /Users/kratzscience/anaconda/lib/python3.4/site-packages/plotly/matplotlylib/mplexporter/exporter.py in run(self, fig)
#      47             import matplotlib.pyplot as plt
#      48             plt.close(fig)
# ---> 49         self.crawl_fig(fig)
#      50
#      51     @staticmethod
#
# /Users/kratzscience/anaconda/lib/python3.4/site-packages/plotly/matplotlylib/mplexporter/exporter.py in crawl_fig(self, fig)
#     112         """Crawl the figure and process all axes"""
#     113         with self.renderer.draw_figure(fig=fig,
# --> 114                                        props=utils.get_figure_properties(fig)):
#     115             for ax in fig.axes:
#     116                 self.crawl_ax(ax)
#
# /Users/kratzscience/anaconda/lib/python3.4/contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# /Users/kratzscience/anaconda/lib/python3.4/site-packages/plotly/matplotlylib/mplexporter/renderers/base.py in draw_figure(self, fig, props)
#      41         self._current_fig = fig
#      42         self._fig_props = props
# ---> 43         self.open_figure(fig=fig, props=props)
#      44         yield
#      45         self.close_figure(fig=fig)
#
# /Users/kratzscience/anaconda/lib/python3.4/site-packages/plotly/matplotlylib/renderer.py in open_figure(self, fig, props)
#      83             autosize=False,
#      84             hovermode='closest')
# ---> 85         self.mpl_x_bounds, self.mpl_y_bounds = mpltools.get_axes_bounds(fig)
#      86         margin = go.Margin(
#      87             l=int(self.mpl_x_bounds[0] * self.plotly_fig['layout']['width']),
#
# /Users/kratzscience/anaconda/lib/python3.4/site-packages/plotly/matplotlylib/mpltools.py in get_axes_bounds(fig)
#     204         y_min.append(bounds[1])
#     205         y_max.append(bounds[1]+bounds[3])
# --> 206     x_min, y_min, x_max, y_max = min(x_min), min(y_min), max(x_max), max(y_max)
#     207     return (x_min, x_max), (y_min, y_max)
#     208
#
# ValueError: min() arg is an empty sequence
